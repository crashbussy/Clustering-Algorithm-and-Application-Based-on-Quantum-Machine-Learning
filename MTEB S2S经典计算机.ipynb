# %%
from mteb import MTEB 
from sentence_transformers import SentenceTransformer
# Define the sentence-transformers model name、
model_name = "all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)
evaluation = MTEB(tasks=["ArxivClusteringS2S"])
results = evaluation.run(model, output_folder=f"results/{model_name}")
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - ArxivClusteringS2S, s2s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# WARNING: ArxivClusteringS2S results already exists. Skipping.

# %%
print(results)
# Out:
# {}

# %%
#以上，准确率为v_measure':0.37742847764830334

# %%
from datasets import load_dataset
dataset = load_dataset('mteb/arxiv-clustering-s2s')
print(dataset)
#data = dataset
#for example in data:     
#    print(example)
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 31
#     })
# })

# %%
print(type(dataset))
print(dataset.cache_files)#查找文件位置
print(dataset.num_columns)#2列31行   获取DatasetDict各个Dataset中数据的列数、行数
print(dataset.num_rows)
print(dataset.column_names)#获取DatasetDict各个Dataset中的列名称
print(dataset.shape)#获取DatasetDict各个Dataset中的数据形状
# Out:
# <class 'datasets.dataset_dict.DatasetDict'>
# {'test': [{'filename': 'C:\\Users\\ZhiShiLang\\.cache\\huggingface\\datasets\\mteb___json\\mteb--arxiv-clustering-s2s-4a15d2854f697cec\\0.0.0\\0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51\\json-test.arrow'}]}
# {'test': 2}
# {'test': 31}
# {'test': ['sentences', 'labels']}
# {'test': (31, 2)}

# %%
print(dataset[ "test" ][30])#可以像这样查看每一组中的数据，一共有31组，也就意味着最多【30】
# Out:
# {'sentences': ['Confinement in the presence of external fields and axions', 'Determining neutralino parameters in Left-Right Supersymmetric Models', 'Model independent constraints on leptoquarks from b -> s l+ l- processes', 'Y-formalism in Pure Spinor Quantization of Superstrings', 'Exact self-accelerating cosmologies in the ghost-free bigravity and\n  massive gravity', 'Parisi-Sourlas supergravity', 'Revisiting the AdS Boson Stars: the Mass-Charge Relations', 'A description of 1/4 BPS configurations in minimal type IIB SUGRA', 'Using Wilson flow to study the SU(3) deconfinement transition', 'Bounded particle interactions driven by a nonlocal dual Chern-Simons\n  model', 'Critical exponents for higher-representation sources in 3D SU(3) gauge\n  theory from CFT', 'Aspects of Magnetic Field Configurations in Planar Nonlinear\n  Electrodynamics', 'Low-energy effective actions in three-dimensional extended SYM theories', 'Hadron masses on a 16^3 x 40 lattice at \\beta = 5.7', 'Predictio
# ...

# %%
sentences = dataset['test'][0]['sentences'][0:100]
print(sentences)
# Out:
# ['Small Perturbations of an Interface for Elastostatic Problems', 'Fitting orbits to tidal streams with proper motions', 'Final Mass and Spin of Merged Black Holes and the Golden Black Hole', 'Heavy meson tomography of cold nuclear matter at the electron-ion\n  collider', 'On the Correlation of Critical Points and Angular Trispectrum for Random\n  Spherical Harmonics', 'In-situ Tuning of the Electric Dipole Strength of a Double Dot Charge\n  Qubit: Charge Noise Protection and Ultra Strong Coupling', 'Semiclassical Coulomb field', 'Formation and Detectability of Terrestrial Planets Around Alpha Centauri\n  B', 'The complex iron line of NGC 5506', 'The Magidor Iteration and Restrictions of Ultrapowers to the Ground\n  Model', 'An overview of the computational aspects of nonunique factorization\n  invariants', 'Predictive Power of Strong Coupling in Theories with Large Distance\n  Modified Gravity', 'Neutralino-neutralino annihilation to photon and gluon pairs in MSSM\n  models', 'Struc
# ...

# %%
for i in data
print()#
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#查看一组中共有几个句子，可用dataset['test'][0]['labels']或者dataset['test'][0]['sentences']
k=0
for i in dataset['test'][0]['labels']:
    k=k+1
print(k)
# Out:
# 25000

# %%
sentences = dataset['test'][0]['sentences']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sentences = dataset['test'][0]['sentences']
#
# NameError: name 'dataset' is not defined

# %%
from datasets import load_dataset
import datasets
#dataset = load_dataset('mteb/arxiv-clustering-s2s') 
#print(dataset)
datasets.list_datasets()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\Tool\Anaconda3\envs\pytorch\lib\site-packages\huggingface_hub\utils\_errors.py:239, in hf_raise_for_status(response, endpoint_name)
#     238 try:
# --> 239     response.raise_for_status()
#     240 except HTTPError as e:
#
# File d:\Tool\Anaconda3\envs\pytorch\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 import datasets
#       3 #dataset = load_dataset('mteb/arxiv-clustering-s2s')
#       4 #print(dataset)
# ...
